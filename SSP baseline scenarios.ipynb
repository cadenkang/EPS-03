# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_table('iamc_db (remade) - Sheet1.csv', sep=',')
data = data.set_index('Year')
plt.plot(data)
data
# Out:
#       SSP3-Baseline  SSP4-Baseline  SSP1-Baseline  SSP2-Baseline  \
# Year
# 2005      34373.935      31887.169      33166.074      37768.994
# 2010      39560.752      35775.775      35488.818      40294.638
# 2020      48502.707      41636.027      40069.004      42262.425
# 2030      55000.887      49069.570      42653.234      46727.551
# 2040      59877.305      53846.929      43778.496      51606.452
# 2050      64001.363      55664.437      42454.758      56651.629
# 2060      67962.295      56953.977      41601.928      61402.269
# 2070      71792.666      55898.208      39217.532      65996.979
# 2080      75571.458      51172.923      33392.294      74133.629
# 2090      80137.183      47532.719      28618.414      81028.377
# 2100      85214.966      44784.722      24612.914      85684.204
#
#       SSP5-Baseline
# Year
# 2005      35279.641
# 2010      36371.125
# 2020      44610.389
# 2030      56726.452
# 2040      69861.617
# 2050      84436.466
# 2060     101301.616
# ...
