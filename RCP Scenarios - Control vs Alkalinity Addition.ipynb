# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from scipy.interpolate import interp1d

# %%
# control RCP 2.6
control26 = pd.read_table('RCP_26.txt', header=None, sep='\s+')
control26[0] = control26[0].astype(int)
control26[0] *= -1
for n in range(1, 9):
    control26[n] = control26[n].astype(float)
control26[7] /= 1000000000000000
control26 = control26.rename({0:'Year', 1:'CO2 Emission', 2:'Atmospheric CO2', 3:'Surface Alkalinity', 
                              4:'Surface Carbonate Concentration', 5:'Omega at Surface', 6:'Surface pH',
                              7:'Annual Alkalinity Added', 8:'Total Alkalinity Added'}, axis=1)
control26 = control26.set_index('Year')
control26
# Out:
#       CO2 Emission  Atmospheric CO2  Surface Alkalinity  \
# Year
# 1980       5.28258          292.584             2258.74
# 1981       5.13855          294.759             2258.74
# 1982       5.10026          296.881             2258.74
# 1983       5.14808          299.004             2258.74
# 1984       5.29806          301.175             2258.74
# ...            ...              ...                 ...
# 2096      -0.26800          472.505             2258.76
# 2097      -0.26800          471.695             2258.76
# 2098      -0.26800          470.889             2258.76
# 2099      -0.26800          470.088             2258.76
# 2100      -0.41960          469.224             2258.76
#
#       Surface Carbonate Concentration  Omega at Surface  Surface pH  \
# Year
# 1980                          168.938           4.20975     8.14703
# 1981                          168.289           4.19357     8.14497
# 1982                          167.585           4.17604     8.14274
# ...

# %%
# control RCP 4.5
control45 = pd.read_table('RCP_45.txt', header=None, sep='\s+')
control45[0] = control45[0].astype(int)
control45[0] *= -1
for n in range(1, 9):
    control45[n] = control45[n].astype(float)
control45[7] /= 1000000000000000
control45 = control45.rename({0:'Year', 1:'CO2 Emission', 2:'Atmospheric CO2', 3:'Surface Alkalinity', 
                              4:'Surface Carbonate Concentration', 5:'Omega at Surface', 6:'Surface pH',
                              7:'Annual Alkalinity Added', 8:'Total Alkalinity Added'}, axis=1)
control45 = control45.set_index('Year')
control45
# Out:
#       CO2 Emission  Atmospheric CO2  Surface Alkalinity  \
# Year
# 1980       5.28258          292.584             2258.74
# 1981       5.13855          294.759             2258.74
# 1982       5.10026          296.881             2258.74
# 1983       5.14808          299.004             2258.74
# 1984       5.29806          301.175             2258.74
# ...            ...              ...                 ...
# 2096       4.21960          629.176             2258.76
# 2097       4.21960          629.924             2258.76
# 2098       4.21960          630.672             2258.76
# 2099       4.21960          631.422             2258.76
# 2100       4.24900          632.186             2258.76
#
#       Surface Carbonate Concentration  Omega at Surface  Surface pH  \
# Year
# 1980                         168.9380           4.20975     8.14703
# 1981                         168.2890           4.19357     8.14497
# 1982                         167.5850           4.17604     8.14274
# ...

# %%
# control RCP 6.0
control6 = pd.read_table('RCP_6.txt', header=None, sep='\s+')
control6[0] = control6[0].astype(int)
control6[0] *= -1
for n in range(1, 9):
    control6[n] = control6[n].astype(float)
control6[7] /= 1000000000000000
control6 = control6.rename({0:'Year', 1:'CO2 Emission', 2:'Atmospheric CO2', 3:'Surface Alkalinity', 
                              4:'Surface Carbonate Concentration', 5:'Omega at Surface', 6:'Surface pH',
                              7:'Annual Alkalinity Added', 8:'Total Alkalinity Added'}, axis=1)
control6 = control6.set_index('Year')
control6
# Out:
#       CO2 Emission  Atmospheric CO2  Surface Alkalinity  \
# Year
# 1980       5.28258          292.584             2258.74
# 1981       5.13855          294.759             2258.74
# 1982       5.10026          296.881             2258.74
# 1983       5.14808          299.004             2258.74
# 1984       5.29806          301.175             2258.74
# ...            ...              ...                 ...
# 2096      14.55600          773.344             2258.76
# 2097      14.55600          778.457             2258.76
# 2098      14.55600          783.565             2258.76
# 2099      14.55600          788.668             2258.76
# 2100      13.93500          793.485             2258.76
#
#       Surface Carbonate Concentration  Omega at Surface  Surface pH  \
# Year
# 1980                         168.9380           4.20975     8.14703
# 1981                         168.2890           4.19357     8.14497
# 1982                         167.5850           4.17604     8.14274
# ...

# %%
# control RCP 8.5
control85 = pd.read_table('RCP_85.txt', header=None, sep='\s+')
control85[0] = control85[0].astype(int)
control85[0] *= -1
for n in range(1, 9):
    control85[n] = control85[n].astype(float)
control85[7] /= 1000000000000000
control85 = control85.rename({0:'Year', 1:'CO2 Emission', 2:'Atmospheric CO2', 3:'Surface Alkalinity', 
                              4:'Surface Carbonate Concentration', 5:'Omega at Surface', 6:'Surface pH',
                              7:'Annual Alkalinity Added', 8:'Total Alkalinity Added'}, axis=1)
control85 = control85.set_index('Year')
control85
# Out:
#       CO2 Emission  Atmospheric CO2  Surface Alkalinity  \
# Year
# 1980       5.28258          292.584             2258.74
# 1981       5.13855          294.759             2258.74
# 1982       5.10026          296.881             2258.74
# 1983       5.14808          299.004             2258.74
# 1984       5.29806          301.175             2258.74
# ...            ...              ...                 ...
# 2096      28.53100         1039.000             2258.76
# 2097      28.53100         1050.170             2258.76
# 2098      28.53100         1061.320             2258.76
# 2099      28.53100         1072.470             2258.76
# 2100      28.81700         1083.750             2258.77
#
#       Surface Carbonate Concentration  Omega at Surface  Surface pH  \
# Year
# 1980                         168.9380           4.20975     8.14703
# 1981                         168.2890           4.19357     8.14497
# 1982                         167.5850           4.17604     8.14274
# ...

# %%
# RCP 2.6 with alkalinity addition
alka26 = pd.read_table('Caden_RCP26.txt', header=None, sep='\s+')
alka26[0] = alka26[0].astype(int)
alka26[0] *= -1
for n in range(1, 9):
    alka26[n] = alka26[n].astype(float)
alka26[7] /= 1000000000000000
alka26 = alka26.rename({0:'Year', 1:'CO2 Emission', 2:'Atmospheric CO2', 3:'Surface Alkalinity', 
                              4:'Surface Carbonate Concentration', 5:'Omega at Surface', 6:'Surface pH',
                              7:'Annual Alkalinity Added', 8:'Total Alkalinity Added'}, axis=1)
alka26 = alka26.set_index('Year')
alka26
# Out:
#       CO2 Emission  Atmospheric CO2  Surface Alkalinity  \
# Year
# 1980       5.28258          292.584             2258.74
# 1981       5.13855          294.759             2258.74
# 1982       5.10026          296.881             2258.74
# 1983       5.14808          299.004             2258.74
# 1984       5.29806          301.175             2258.74
# ...            ...              ...                 ...
# 4996       0.00000          131.598             2458.73
# 4997       0.00000          131.605             2458.68
# 4998       0.00000          131.611             2458.64
# 4999       0.00000          131.618             2458.59
# 5000       0.00000          131.625             2458.54
#
#       Surface Carbonate Concentration  Omega at Surface  Surface pH  \
# Year
# 1980                          168.938           4.20975     8.14703
# 1981                          168.289           4.19357     8.14497
# 1982                          167.585           4.17604     8.14274
# ...

# %%
# RCP 4.5 with alkalinity addition
alka45 = pd.read_table('Caden_RCP45.txt', header=None, sep='\s+')
alka45[0] = alka45[0].astype(int)
alka45[0] *= -1
for n in range(1, 9):
    alka45[n] = alka45[n].astype(float)
alka45[7] /= 1000000000000000
alka45 = alka45.rename({0:'Year', 1:'CO2 Emission', 2:'Atmospheric CO2', 3:'Surface Alkalinity', 
                              4:'Surface Carbonate Concentration', 5:'Omega at Surface', 6:'Surface pH',
                              7:'Annual Alkalinity Added', 8:'Total Alkalinity Added'}, axis=1)
alka45 = alka45.set_index('Year')
alka45
# Out:
#       CO2 Emission  Atmospheric CO2  Surface Alkalinity  \
# Year
# 1980       5.28258          292.584             2258.74
# 1981       5.13855          294.759             2258.74
# 1982       5.10026          296.881             2258.74
# 1983       5.14808          299.004             2258.74
# 1984       5.29806          301.175             2258.74
# ...            ...              ...                 ...
# 4996       0.00000          144.459             2459.19
# 4997       0.00000          144.467             2459.14
# 4998       0.00000          144.474             2459.10
# 4999       0.00000          144.482             2459.05
# 5000       0.00000          144.490             2459.00
#
#       Surface Carbonate Concentration  Omega at Surface  Surface pH  \
# Year
# 1980                          168.938           4.20975     8.14703
# 1981                          168.289           4.19357     8.14497
# 1982                          167.585           4.17604     8.14274
# ...

# %%
# RCP 6.0 with alkalinity addition
alka6 = pd.read_table('Caden_RCP6.txt', header=None, sep='\s+')
alka6[0] = alka6[0].astype(int)
alka6[0] *= -1
for n in range(1, 9):
    alka6[n] = alka6[n].astype(float)
alka6[7] /= 1000000000000000
alka6 = alka6.rename({0:'Year', 1:'CO2 Emission', 2:'Atmospheric CO2', 3:'Surface Alkalinity', 
                              4:'Surface Carbonate Concentration', 5:'Omega at Surface', 6:'Surface pH',
                              7:'Annual Alkalinity Added', 8:'Total Alkalinity Added'}, axis=1)
alka6 = alka6.set_index('Year')
alka6
# Out:
#       CO2 Emission  Atmospheric CO2  Surface Alkalinity  \
# Year
# 1980       5.28258          292.584             2258.74
# 1981       5.13855          294.759             2258.74
# 1982       5.10026          296.881             2258.74
# 1983       5.14808          299.004             2258.74
# 1984       5.29806          301.175             2258.74
# ...            ...              ...                 ...
# 4996       0.00000          157.348             2459.61
# 4997       0.00000          157.356             2459.56
# 4998       0.00000          157.365             2459.51
# 4999       0.00000          157.374             2459.46
# 5000       0.00000          157.383             2459.41
#
#       Surface Carbonate Concentration  Omega at Surface  Surface pH  \
# Year
# 1980                          168.938           4.20975     8.14703
# 1981                          168.289           4.19357     8.14497
# 1982                          167.585           4.17604     8.14274
# ...

# %%
# RCP 8.5 with alkalinity addition
alka85 = pd.read_table('Caden_RCP85.txt', header=None, sep='\s+')
alka85[0] = alka85[0].astype(int)
alka85[0] *= -1
for n in range(1, 9):
    alka85[n] = alka85[n].astype(float)
alka85[7] /= 1000000000000000
alka85 = alka85.rename({0:'Year', 1:'CO2 Emission', 2:'Atmospheric CO2', 3:'Surface Alkalinity', 
                              4:'Surface Carbonate Concentration', 5:'Omega at Surface', 6:'Surface pH',
                              7:'Annual Alkalinity Added', 8:'Total Alkalinity Added'}, axis=1)
alka85 = alka85.set_index('Year')
alka85
# Out:
#       CO2 Emission  Atmospheric CO2  Surface Alkalinity  \
# Year
# 1980       5.28258          292.584             2258.74
# 1981       5.13855          294.759             2258.74
# 1982       5.10026          296.881             2258.74
# 1983       5.14808          299.004             2258.74
# 1984       5.29806          301.175             2258.74
# ...            ...              ...                 ...
# 4996       0.00000          184.356             2460.83
# 4997       0.00000          184.367             2460.78
# 4998       0.00000          184.378             2460.73
# 4999       0.00000          184.389             2460.69
# 5000       0.00000          184.400             2460.64
#
#       Surface Carbonate Concentration  Omega at Surface  Surface pH  \
# Year
# 1980                          168.938           4.20975     8.14703
# 1981                          168.289           4.19357     8.14497
# 1982                          167.585           4.17604     8.14274
# ...

# %%
# Column 1: CO2 Emission

fig1 = plt.figure()
axl = fig1.add_subplot(111)

# control
"""
col1_c26 = control26.iloc[40:,0]
col1_c45 = control45.iloc[40:,0]
col1_c6 = control6.iloc[40:,0]
col1_c85 = control85.iloc[40:,0]
axl.plot(col1_c26, label='2.6', alpha=0.9, linewidth=3.5, color='tab:blue')
axl.plot(col1_c45, label='4.5', alpha=0.9, linewidth=3.5, color='tab:orange')
axl.plot(col1_c6, label='6.0', alpha=0.9, linewidth=3.5, color='tab:green')
axl.plot(col1_c85, label='8.5', alpha=0.9, linewidth=3.5, color='tab:red')
"""

# alkalinity addition
col1_a26 = alka26.iloc[40:121,0]
col1_a45 = alka45.iloc[40:121,0]
col1_a6 = alka6.iloc[40:121,0]
col1_a85 = alka85.iloc[40:121,0]
axl.plot(col1_a26, label='2.6 (ALK)', linewidth=3.5, color='tab:blue')
axl.plot(col1_a45, label='4.5 (ALK)', linewidth=3.5, color='tab:orange')
axl.plot(col1_a6, label='6.0 (ALK)', linewidth=3.5, color='tab:green')
axl.plot(col1_a85, label='8.5 (ALK)', linewidth=3.5, color='tab:red')

axl.legend(title='RCP Scenarios', prop={'size':12}, title_fontsize=14)
axl.grid(color='silver', b=True, which='both')
axl.set_facecolor('aliceblue')
axl.set_title('$CO_{2}$ Emission (Alkalinity Addition)', fontsize=22, fontweight='bold')
axl.tick_params(axis='both', labelsize=14)
plt.xlabel('Year', fontsize=16)
plt.ylabel('$CO_{2}$ (Gt/yr)', fontsize=16)

txt = "*ALK = Alkalinity Addition"
plt.text(2020, 0, txt, ha='left', fontsize=16)

params = {'mathtext.default':'regular'}          
plt.rcParams.update(params)

fig1.set_size_inches(12, 8)

# %%
# Column 2: Atmospheric CO2

fig2 = plt.figure()
axl = fig2.add_subplot(211)
axl2 = fig2.add_subplot(212)

# control
col2_c26 = control26.iloc[40:,1]
col2_c45 = control45.iloc[40:,1]
col2_c6 = control6.iloc[40:,1]
col2_c85 = control85.iloc[40:,1]

axl.plot(col2_c26, label='2.6', linewidth=3.5, color='tab:blue')
axl.plot(col2_c45, label='4.5', linewidth=3.5, color='tab:orange')
axl.plot(col2_c6, label='6.0', linewidth=3.5, color='tab:green')
axl.plot(col2_c85, label='8.5', linewidth=3.5, color='tab:red')

# alkalinity addition (until 2100)
col2_a26_1 = alka26.iloc[40:121,1]
col2_a45_1 = alka45.iloc[40:121,1]
col2_a6_1 = alka6.iloc[40:121,1]
col2_a85_1 = alka85.iloc[40:121,1]

axl.plot(col2_a26_1, label='2.6 (ALK)', linewidth=3.5, color='indigo')
axl.plot(col2_a45_1, label='4.5 (ALK)', linewidth=3.5, color='maroon')
axl.plot(col2_a6_1, label='6.0 (ALK)', linewidth=3.5, color='fuchsia')
axl.plot(col2_a85_1, label='8.5 (ALK)', linewidth=3.5, color='navy')

axl.legend(title='RCP Scenarios', prop={'size':12}, title_fontsize=14)
axl.grid(color='silver', b=True, which='both')
axl.set_facecolor('aliceblue')
axl.set_title('Atmospheric $CO_{2}$ (until 2100)', fontsize=22, fontweight='bold')
axl.set_xlabel('Year', fontsize=16)
axl.set_ylabel('$CO_{2}$ (ppm)', fontsize=16)
axl.tick_params(axis='both', labelsize=14)

# alkalinity addition (past 2100)
col2_a26_2 = alka26.iloc[120:321,1]
col2_a45_2 = alka45.iloc[120:321,1]
col2_a6_2 = alka6.iloc[120:321,1]
col2_a85_2 = alka85.iloc[120:321,1]

axl2.plot(col2_a26_2, label='2.6 (ALK)', linewidth=3.5, color='indigo')
axl2.plot(col2_a45_2, label='4.5 (ALK)', linewidth=3.5, color='maroon')
axl2.plot(col2_a6_2, label='6.0 (ALK)', linewidth=3.5, color='fuchsia')
axl2.plot(col2_a85_2, label='8.5 (ALK)', linewidth=3.5, color='navy')

axl2.legend(title='RCP Scenarios', prop={'size':12}, title_fontsize=14)
axl2.grid(color='silver', b=True, which='both')
axl2.set_facecolor('aliceblue')
axl2.set_title('Atmospheric $CO_{2}$ (past 2100)', fontsize=22, fontweight='bold')
axl2.set_xlabel('Year', fontsize=16)
axl2.set_ylabel('$CO_{2}$ (ppm)', fontsize=16)
axl2.tick_params(axis='both', labelsize=14)

params = {'mathtext.default':'regular'}          
plt.rcParams.update(params)

fig2.set_size_inches(12, 16)

# %%
# Column 3: Surface Alkalinity

fig3 = plt.figure()
axl = fig3.add_subplot(211)
axl2 = fig3.add_subplot(212)

# control
col3_c26 = control26.iloc[85:,2]
col3_c45 = control45.iloc[85:,2]
col3_c6 = control6.iloc[85:,2]
col3_c85 = control85.iloc[85:,2]

axl.plot(col3_c26, label='2.6', linewidth=3.5, color='tab:blue')
axl.plot(col3_c45, label='4.5', linewidth=3.5, color='tab:orange')
axl.plot(col3_c6, label='6.0', linewidth=3.5, color='tab:green')
axl.plot(col3_c85, label='8.5', linewidth=3.5, color='tab:red')

axl.legend(title='RCP Scenarios', prop={'size':12}, title_fontsize=14)
axl.grid(color='silver', b=True, which='both')
axl.set_facecolor('aliceblue')
axl.set_title('Surface Alkalinity (Control)', fontsize=22, fontweight='bold')
axl.set_xlabel('Year', fontsize=16)
axl.set_ylabel('Alkalinity (µmol/kg)', fontsize=16)
axl.tick_params(axis='both', labelsize=14)

# alkalinity addition
col3_a26 = alka26.iloc[45:221,2]
col3_a45 = alka45.iloc[45:221,2]
col3_a6 = alka6.iloc[45:221,2]
col3_a85 = alka85.iloc[45:221,2]

axl2.plot(col3_a26, label='2.6 (ALK)', linewidth=3.5, color='indigo')
axl2.plot(col3_a45, label='4.5 (ALK)', linewidth=3.5, color='maroon')
axl2.plot(col3_a6, label='6.0 (ALK)', linewidth=3.5, color='fuchsia')
axl2.plot(col3_a85, label='8.5 (ALK)', linewidth=3.5, color='navy')

axl2.legend(title='RCP Scenarios', prop={'size':12}, title_fontsize=14)
axl2.grid(color='silver', b=True, which='both')
axl2.set_facecolor('aliceblue')
axl2.set_title('Surface Alkalinity (Alkalinity Addition)', fontsize=22, fontweight='bold')
axl2.set_xlabel('Year', fontsize=16)
axl2.set_ylabel('Alkalinity (µmol/kg)', fontsize=16)
axl2.tick_params(axis='both', labelsize=14)

params = {'mathtext.default':'regular'}          
plt.rcParams.update(params)

fig3.set_size_inches(12, 16)

# %%
# Column 4: Surface Carbonate Concentration

fig4 = plt.figure()
axl = fig4.add_subplot(211)
axl2 = fig4.add_subplot(212)

# control
col4_c26 = control26.iloc[40:,3]
col4_c45 = control45.iloc[40:,3]
col4_c6 = control6.iloc[40:,3]
col4_c85 = control85.iloc[40:,3]

axl.plot(col4_c26, label='2.6', linewidth=3.5, color='tab:blue')
axl.plot(col4_c45, label='4.5', linewidth=3.5, color='tab:orange')
axl.plot(col4_c6, label='6.0', linewidth=3.5, color='tab:green')
axl.plot(col4_c85, label='8.5', linewidth=3.5, color='tab:red')

axl.legend(title='RCP Scenarios', prop={'size':12}, title_fontsize=14)
axl.grid(color='silver', b=True, which='both')
axl.set_facecolor('aliceblue')
axl.set_title('Surface Carbonate ($CO_{3}$$^{2-}$) Concentration (Control)', fontsize=20, fontweight='bold')
axl.set_xlabel('Year', fontsize=16)
axl.set_ylabel('$CO_{3}$$^{2-}$ (µmol/kg)', fontsize=16)
axl.tick_params(axis='both', labelsize=14)

# alkalinity addition
col4_a26 = alka26.iloc[80:181,3]
col4_a45 = alka45.iloc[80:181,3]
col4_a6 = alka6.iloc[80:181,3]
col4_a85 = alka85.iloc[80:181,3]

axl2.plot(col4_a26, label='2.6 (ALK)', linewidth=3.5, color='indigo')
axl2.plot(col4_a45, label='4.5 (ALK)', linewidth=3.5, color='maroon')
axl2.plot(col4_a6, label='6.0 (ALK)', linewidth=3.5, color='fuchsia')
axl2.plot(col4_a85, label='8.5 (ALK)', linewidth=3.5, color='navy')

axl2.legend(title='RCP Scenarios', prop={'size':12}, title_fontsize=14)
axl2.grid(color='silver', b=True, which='both')
axl2.set_facecolor('aliceblue')
axl2.set_title('Surface Carbonate ($CO_{3}$$^{2-}$) Concentration (Alkalinity Addition)', fontsize=18, fontweight='bold')
axl2.set_xlabel('Year', fontsize=16)
axl2.set_ylabel('$CO_{3}$$^{2-}$ (µmol/kg)', fontsize=16)
axl2.tick_params(axis='both', labelsize=14)

params = {'mathtext.default':'regular'}          
plt.rcParams.update(params)

fig4.set_size_inches(12, 16)

# %%
# Column 5: Omega (Ω) at Surface

fig5 = plt.figure()
axl = fig5.add_subplot(211)
axl2 = fig5.add_subplot(212)

# control
col5_c26 = control26.iloc[40:,4]
col5_c45 = control45.iloc[40:,4]
col5_c6 = control6.iloc[40:,4]
col5_c85 = control85.iloc[40:,4]

axl.plot(col5_c26, label='2.6', linewidth=3.5, color='tab:blue')
axl.plot(col5_c45, label='4.5', linewidth=3.5, color='tab:orange')
axl.plot(col5_c6, label='6.0', linewidth=3.5, color='tab:green')
axl.plot(col5_c85, label='8.5', linewidth=3.5, color='tab:red')

axl.legend(title='RCP Scenarios', prop={'size':12}, title_fontsize=14)
axl.grid(color='silver', b=True, which='both')
axl.set_facecolor('aliceblue')
axl.set_title('Calcium Carbonate Saturation State (Ω) at Surface (Control)', fontsize=18, fontweight='bold')
axl.set_xlabel('Year', fontsize=16)
axl.set_ylabel('Ω', fontsize=16)
axl.tick_params(axis='both', labelsize=14)

# alkalinity addition
col5_a26 = alka26.iloc[80:181,4]
col5_a45 = alka45.iloc[80:181,4]
col5_a6 = alka6.iloc[80:181,4]
col5_a85 = alka85.iloc[80:181,4]

axl2.plot(col5_a26, label='2.6 (ALK)', linewidth=3.5, color='indigo')
axl2.plot(col5_a45, label='4.5 (ALK)', linewidth=3.5, color='maroon')
axl2.plot(col5_a6, label='6.0 (ALK)', linewidth=3.5, color='fuchsia')
axl2.plot(col5_a85, label='8.5 (ALK)', linewidth=3.5, color='navy')

axl2.legend(title='RCP Scenarios', prop={'size':12}, title_fontsize=14)
axl2.grid(color='silver', b=True, which='both')
axl2.set_facecolor('aliceblue')
axl2.set_title('Calcium Carbonate Saturation State (Ω) at Surface (Alkalinity Addition)', fontsize=16, fontweight='bold')
axl2.set_xlabel('Year', fontsize=16)
axl2.set_ylabel('Ω', fontsize=16)
axl2.tick_params(axis='both', labelsize=14)

params = {'mathtext.default':'regular'}          
plt.rcParams.update(params)

fig5.set_size_inches(12, 16)

# %%
# Column 6: Surface pH

fig6 = plt.figure()
axl = fig6.add_subplot(211)
axl2 = fig6.add_subplot(212)

# control
col6_c26 = control26.iloc[40:,5]
col6_c45 = control45.iloc[40:,5]
col6_c6 = control6.iloc[40:,5]
col6_c85 = control85.iloc[40:,5]

axl.plot(col6_c26, label='2.6', linewidth=3.5, color='tab:blue')
axl.plot(col6_c45, label='4.5', linewidth=3.5, color='tab:orange')
axl.plot(col6_c6, label='6.0', linewidth=3.5, color='tab:green')
axl.plot(col6_c85, label='8.5', linewidth=3.5, color='tab:red')

# alkalinity addition (until 2100)
col6_a26 = alka26.iloc[40:121,5]
col6_a45 = alka45.iloc[40:121,5]
col6_a6 = alka6.iloc[40:121,5]
col6_a85 = alka85.iloc[40:121,5]

axl.plot(col6_a26, label='2.6 (ALK)', linewidth=3.5, color='indigo')
axl.plot(col6_a45, label='4.5 (ALK)', linewidth=3.5, color='maroon')
axl.plot(col6_a6, label='6.0 (ALK)', linewidth=3.5, color='fuchsia')
axl.plot(col6_a85, label='8.5 (ALK)', linewidth=3.5, color='navy')

axl.legend(title='RCP Scenarios', prop={'size':12}, title_fontsize=14)
axl.grid(color='silver', b=True, which='both')
axl.set_facecolor('aliceblue')
axl.set_title('Surface pH (until 2100)', fontsize=22, fontweight='bold')
axl.set_xlabel('Year', fontsize=16)
axl.set_ylabel('pH', fontsize=16)
axl.tick_params(axis='both', labelsize=14)

# alkalinity addition (past 2100)
col6_a26 = alka26.iloc[120:221,5]
col6_a45 = alka45.iloc[120:221,5]
col6_a6 = alka6.iloc[120:221,5]
col6_a85 = alka85.iloc[120:221,5]

axl2.plot(col6_a26, label='2.6 (ALK)', linewidth=3.5, color='indigo')
axl2.plot(col6_a45, label='4.5 (ALK)', linewidth=3.5, color='maroon')
axl2.plot(col6_a6, label='6.0 (ALK)', linewidth=3.5, color='fuchsia')
axl2.plot(col6_a85, label='8.5 (ALK)', linewidth=3.5, color='navy')

axl2.legend(title='RCP Scenarios', prop={'size':12}, title_fontsize=14)
axl2.grid(color='silver', b=True, which='both')
axl2.set_facecolor('aliceblue')
axl2.set_title('Surface pH (past 2100)', fontsize=22, fontweight='bold')
axl2.set_xlabel('Year', fontsize=16)
axl2.set_ylabel('pH', fontsize=16)
axl2.tick_params(axis='both', labelsize=14)

params = {'mathtext.default':'regular'}          
plt.rcParams.update(params)

fig6.set_size_inches(12, 16)

# %%
# Column 7: Annual Alkalinity Added

fig7 = plt.figure()
axl = fig7.add_subplot(111)

"""
# control
col7_c26 = control26.iloc[:,6]
col7_c45 = control45.iloc[:,6]
col7_c6 = control6.iloc[:,6]
col7_c85 = control85.iloc[:,6]

axl.plot(col7_c26, label='2.6', linewidth=3.5, color='tab:blue')
axl.plot(col7_c45, label='4.5', linewidth=3.5, color='tab:orange')
axl.plot(col7_c6, label='6.0', linewidth=3.5, color='tab:green')
axl.plot(col7_c85, label='8.5', linewidth=3.5, color='tab:red')
"""

# alkalinity addition
col7_a26 = alka26.iloc[40:121,6]
col7_a45 = alka45.iloc[40:121,6]
col7_a6 = alka6.iloc[40:121,6]
col7_a85 = alka85.iloc[40:121,6]

axl.plot(col7_a26, label='2.6 (ALK)', linewidth=3.5, color='tab:blue')
axl.plot(col7_a45, label='4.5 (ALK)', linewidth=3.5, color='tab:orange')
axl.plot(col7_a6, label='6.0 (ALK)', linewidth=3.5, color='tab:green')
axl.plot(col7_a85, label='8.5 (ALK)', linewidth=3.5, color='tab:red')

axl.legend(title='RCP Scenarios', prop={'size':12}, title_fontsize=14)
axl.grid(color='silver', b=True, which='both')
axl.set_facecolor('aliceblue')
axl.set_title('Annual Alkalinity Added', fontsize=22, fontweight='bold')
axl.tick_params(axis='both', labelsize=14)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Alkalinity (Pmol/yr)', fontsize=16)

txt = "*Total Alkalinity Added: 4.450000e+17 mol"
plt.text(2080, 0, txt, ha='center', fontsize=14)

params = {'mathtext.default':'regular'}          
plt.rcParams.update(params)

fig7.set_size_inches(12, 8)

# %%
pdf = PdfPages('figures.pdf')
pdf.savefig(fig1)
pdf.savefig(fig2)
pdf.savefig(fig3)
pdf.savefig(fig4)
pdf.savefig(fig5)
pdf.savefig(fig6)
pdf.savefig(fig7)
pdf.close()

# %%
# Column 8: Total Alkalinity Added

"""
fig = plt.figure()
axl = fig.add_subplot(111)

# control
col8_c26 = control26.iloc[:,7]
col8_c45 = control45.iloc[:,7]
col8_c6 = control6.iloc[:,7]
col8_c85 = control85.iloc[:,7]

axl.plot(col8_c26, label='2.6', linewidth=3.5, color='tab:blue')
axl.plot(col8_c45, label='4.5', linewidth=3.5, color='tab:orange')
axl.plot(col8_c6, label='6.0', linewidth=3.5, color='tab:green')
axl.plot(col8_c85, label='8.5', linewidth=3.5, color='tab:red')

# alkalinity addition
col8_a26 = alka26.iloc[:171,7]
col8_a45 = alka45.iloc[:171,7]
col8_a6 = alka6.iloc[:171,7]
col8_a85 = alka85.iloc[:171,7]

axl.plot(col8_a26, label='2.6 (ALK)', linewidth=3.5, color='indigo')
axl.plot(col8_a45, label='4.5 (ALK)', linewidth=3.5, color='maroon')
axl.plot(col8_a6, label='6.0 (ALK)', linewidth=3.5, color='fuchsia')
axl.plot(col8_a85, label='8.5 (ALK)', linewidth=3.5, color='navy')

axl.legend(title='RCP Scenarios', prop={'size': 10}, title_fontsize=11.5)
axl.grid(color='silver', b=True, which='both')
axl.set_facecolor('aliceblue')
axl.set_title('Total Alkalinity Added', fontsize=18, fontweight='bold')
plt.xlabel('Year', fontsize=13)
plt.xticks(fontsize=11)
plt.ylabel('Alkalinity (mol)', fontsize=13)
plt.yticks(fontsize=11)

params = {'mathtext.default':'regular'}          
plt.rcParams.update(params)
"""
# Out:
# "\nfig = plt.figure()\naxl = fig.add_subplot(111)\n\n# control\ncol8_c26 = control26.iloc[:,7]\ncol8_c45 = control45.iloc[:,7]\ncol8_c6 = control6.iloc[:,7]\ncol8_c85 = control85.iloc[:,7]\n\naxl.plot(col8_c26, label='2.6', linewidth=3.5, color='tab:blue')\naxl.plot(col8_c45, label='4.5', linewidth=3.5, color='tab:orange')\naxl.plot(col8_c6, label='6.0', linewidth=3.5, color='tab:green')\naxl.plot(col8_c85, label='8.5', linewidth=3.5, color='tab:red')\n\n# alkalinity addition\ncol8_a26 = alka26.iloc[:171,7]\ncol8_a45 = alka45.iloc[:171,7]\ncol8_a6 = alka6.iloc[:171,7]\ncol8_a85 = alka85.iloc[:171,7]\n\naxl.plot(col8_a26, label='2.6 (ALK)', linewidth=3.5, color='indigo')\naxl.plot(col8_a45, label='4.5 (ALK)', linewidth=3.5, color='maroon')\naxl.plot(col8_a6, label='6.0 (ALK)', linewidth=3.5, color='fuchsia')\naxl.plot(col8_a85, label='8.5 (ALK)', linewidth=3.5, color='navy')\n\naxl.legend(title='RCP Scenarios', prop={'size': 10}, title_fontsize=11.5)\naxl.grid(color='silver', b=True, 
# ...
